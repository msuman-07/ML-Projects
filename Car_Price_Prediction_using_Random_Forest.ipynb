# %% [markdown]
# <a href="https://colab.research.google.com/github/msuman-07/ML-Projects/blob/main/Car_Price_Prediction_using_Random_Forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *Import Lib*

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0858c805-0b6b-4bf2-bb3a-fab6d8b66aa7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0858c805-0b6b-4bf2-bb3a-fab6d8b66aa7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# *Load Dataset*

# %%
dataset = pd.read_csv('CarPrice Dataset.csv')

# %% [markdown]
# *Summarize Dataset*

# %%
print(dataset.shape)
print(dataset.head(5))
# Out:
# (199, 26)
#    symboling normalized-losses         make fuel-type  ... peak-rpm city-mpg highway-mpg  price
# 0          3                 ?  alfa-romero       gas  ...     5000       21          27  13495
# 1          3                 ?  alfa-romero       gas  ...     5000       21          27  16500
# 2          1                 ?  alfa-romero       gas  ...     5000       19          26  16500
# 3          2               164         audi       gas  ...     5500       24          30  13950
# 4          2               164         audi       gas  ...     5500       18          22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# *Splitting Dataset into X & Y*
#
# This X contains Both Numerical & Text Data

# %%
Xdata = dataset.drop('price',axis='columns')
numericalCols=Xdata.select_dtypes (exclude=['object']).columns
X=Xdata[numericalCols]
X
# Out:
#      symboling  wheel-base  length  width  ...  horsepower  peak-rpm  city-mpg  highway-mpg
# 0            3        88.6   168.8   64.1  ...         111      5000        21           27
# 1            3        88.6   168.8   64.1  ...         111      5000        21           27
# 2            1        94.5   171.2   65.5  ...         154      5000        19           26
# 3            2        99.8   176.6   66.2  ...         102      5500        24           30
# 4            2        99.4   176.6   66.4  ...         115      5500        18           22
# ..         ...         ...     ...    ...  ...         ...       ...       ...          ...
# 194         -1       109.1   188.8   68.9  ...         114      5400        23           28
# 195         -1       109.1   188.8   68.8  ...         160      5300        19           25
# 196         -1       109.1   188.8   68.9  ...         134      5500        18           23
# ...

# %%
Y = dataset ['price']
Y
# Out:
# 0      13495
# 1      16500
# 2      16500
# 3      13950
# 4      17450
#        ...
# 194    16845
# 195    19045
# 196    21485
# 197    22470
# 198    22625
# Name: price, Length: 199, dtype: object

# %% [markdown]
# *Scaling the Independent Variables (Features)*

# %%
from sklearn.preprocessing import scale
cols = X.columns
pd.DataFrame(scale (X))
X.columns = cols
X
# Out:
#      symboling  wheel-base  length  width  ...  horsepower  peak-rpm  city-mpg  highway-mpg
# 0            3        88.6   168.8   64.1  ...         111      5000        21           27
# 1            3        88.6   168.8   64.1  ...         111      5000        21           27
# 2            1        94.5   171.2   65.5  ...         154      5000        19           26
# 3            2        99.8   176.6   66.2  ...         102      5500        24           30
# 4            2        99.4   176.6   66.4  ...         115      5500        18           22
# ..         ...         ...     ...    ...  ...         ...       ...       ...          ...
# 194         -1       109.1   188.8   68.9  ...         114      5400        23           28
# 195         -1       109.1   188.8   68.8  ...         160      5300        19           25
# 196         -1       109.1   188.8   68.9  ...         134      5500        18           23
# ...

# %%
# Replace '?' with NaN
dataset.replace('?', np.nan, inplace=True)

# Convert numeric columns to proper data type
for col in dataset.columns:
    try:
        dataset[col] = pd.to_numeric(dataset[col])  # Convert numeric columns
    except ValueError:
        pass  # Ignore conversion errors for non-numeric columns

# Fill missing numeric values with column mean
dataset.fillna(dataset.mean(numeric_only=True), inplace=True)

# Convert categorical columns to numeric using one-hot encoding
dataset = pd.get_dummies(dataset)

# Define features and target
X = dataset.drop(columns=['price'])
y = dataset['price']

# %% [markdown]
# *Splitting Dataset into Train & Test*

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

# %% [markdown]
# *Training using Random Forest*

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# *Evaluating Model*

# %%
ypred = model.predict(x_test)
from sklearn.metrics import r2_score
r2score = r2_score(y_test,ypred)
print("R2Score",r2score*100)
# Out:
# R2Score 86.40438936394972
